# %%
import pandas as pd

data = pd.read_csv('/workspace/GABRYEL_ALENCAR_DDF_TECH_072024/data/processed/df_processed_orders2.csv')
data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       10a045cdf6a5650c21e9cfeb60384c16                   1      voucher
# 1       b059ee4de278302d550a3035c4cdb740                   1      voucher
# 2       a2ac6dad85cf8af5b0afb510a240fe8c                   1      voucher
# 3       616fa7d4871b87832197b2a137a115d2                   1      voucher
# 4       392ed9afd714e3c74767d0c4d3e3f477                   1      voucher
# ...                                  ...                 ...          ...
# 103881  3b697a20d9e427646d92567910af6d57                   1       boleto
# 103882  71303d7e93b399f5bcd537d124c0bcfa                   1  credit_card
# 103883  809a282bbd5dbcabb6f2f724fca862ec                   1  credit_card
# 103884  e5fa5a7210941f7d56d0208e4e071d35                   1  credit_card
# 103885  2e7a8482f6fb09756ca50c10d7bfc047                   1  credit_card
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %%
from ydata_profiling import ProfileReport

# Carregar os dados
data = pd.read_csv('/workspace/GABRYEL_ALENCAR_DDF_TECH_072024/data/processed/df_processed_orders2.csv')

# Gerar o relatório de perfil dos dados
profile = ProfileReport(data, title="Relatório de Qualidade dos Dados", explorative=True)

# Salvar o relatório como um arquivo HTML
profile.to_file("data_quality_report.html")

# Exibir o relatório
profile.to_notebook_iframe()
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v4.8.3&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-07-13 01:23:03.924012&quot;&gt;&lt;title&gt;Relatório de Qualidade dos Dados&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
