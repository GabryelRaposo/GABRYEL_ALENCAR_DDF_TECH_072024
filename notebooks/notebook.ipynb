# %%
import pandas as pd
data = pd.read_csv('/workspace/GABRYEL_ALENCAR_DDF_TECH_072024/data/raw/olist_customers_dataset.csv')
data2 = pd.read_csv('/workspace/GABRYEL_ALENCAR_DDF_TECH_072024/data/raw/olist_order_payments_dataset.csv')
data3 = pd.read_csv('/workspace/GABRYEL_ALENCAR_DDF_TECH_072024/data/raw/olist_orders_dataset.csv')

print(len(data))
print(len(data2))
print(len(data3))
# Out:
# 99441
# 103886
# 99441

# %%
data.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
data3.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
result = pd.merge(data2, data3, on='order_id', how='inner')

# %%
result
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id  \
# ...

# %%
result = pd.merge(result, data, on='customer_id', how='inner')

# %%
result = result.sort_values(by='order_purchase_timestamp', ascending=False)
result
# Out:
#                                order_id  payment_sequential payment_type  \
# 10552  10a045cdf6a5650c21e9cfeb60384c16                   1      voucher
# 5106   b059ee4de278302d550a3035c4cdb740                   1      voucher
# 64016  a2ac6dad85cf8af5b0afb510a240fe8c                   1      voucher
# 35636  616fa7d4871b87832197b2a137a115d2                   1      voucher
# 95315  392ed9afd714e3c74767d0c4d3e3f477                   1      voucher
# ...                                 ...                 ...          ...
# 155    3b697a20d9e427646d92567910af6d57                   1       boleto
# 32924  71303d7e93b399f5bcd537d124c0bcfa                   1  credit_card
# 58826  809a282bbd5dbcabb6f2f724fca862ec                   1  credit_card
# 61536  e5fa5a7210941f7d56d0208e4e071d35                   1  credit_card
# 27216  2e7a8482f6fb09756ca50c10d7bfc047                   1  credit_card
#
#        payment_installments  payment_value                       customer_id  \
# ...

# %%
df_processed = result.drop(columns=[
    'order_approved_at', 
    'order_delivered_carrier_date', 
    'order_delivered_customer_date', 
    'order_estimated_delivery_date'
])

# %%
df_processed
# Out:
#                                order_id  payment_sequential payment_type  \
# 10552  10a045cdf6a5650c21e9cfeb60384c16                   1      voucher
# 5106   b059ee4de278302d550a3035c4cdb740                   1      voucher
# 64016  a2ac6dad85cf8af5b0afb510a240fe8c                   1      voucher
# 35636  616fa7d4871b87832197b2a137a115d2                   1      voucher
# 95315  392ed9afd714e3c74767d0c4d3e3f477                   1      voucher
# ...                                 ...                 ...          ...
# 155    3b697a20d9e427646d92567910af6d57                   1       boleto
# 32924  71303d7e93b399f5bcd537d124c0bcfa                   1  credit_card
# 58826  809a282bbd5dbcabb6f2f724fca862ec                   1  credit_card
# 61536  e5fa5a7210941f7d56d0208e4e071d35                   1  credit_card
# 27216  2e7a8482f6fb09756ca50c10d7bfc047                   1  credit_card
#
#        payment_installments  payment_value                       customer_id  \
# ...

# %%
dfll = dfll.drop(columns=['Unnamed: 0'])
dfll.to_csv('/workspace/GABRYEL_ALENCAR_DDF_TECH_072024/data/processed/df_processed_orders2.csv', index = False)

# %%
dfll = pd.read_csv('/workspace/GABRYEL_ALENCAR_DDF_TECH_072024/data/processed/df_processed_orders1.csv')
dfll
# Out:
#         Unnamed: 0                          order_id  payment_sequential  \
# 0            10552  10a045cdf6a5650c21e9cfeb60384c16                   1
# 1             5106  b059ee4de278302d550a3035c4cdb740                   1
# 2            64016  a2ac6dad85cf8af5b0afb510a240fe8c                   1
# 3            35636  616fa7d4871b87832197b2a137a115d2                   1
# 4            95315  392ed9afd714e3c74767d0c4d3e3f477                   1
# ...            ...                               ...                 ...
# 103881         155  3b697a20d9e427646d92567910af6d57                   1
# 103882       32924  71303d7e93b399f5bcd537d124c0bcfa                   1
# 103883       58826  809a282bbd5dbcabb6f2f724fca862ec                   1
# 103884       61536  e5fa5a7210941f7d56d0208e4e071d35                   1
# 103885       27216  2e7a8482f6fb09756ca50c10d7bfc047                   1
#
#        payment_type  payment_installments  payment_value  \
# ...
